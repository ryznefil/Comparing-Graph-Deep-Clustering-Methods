# %%
import os
import Utils
import Plotting
import Non_DL_Methods
import numpy as np
from sklearn.metrics import normalized_mutual_info_score

# %% [markdown]
# LOUVAIN

# %%
data_folder = '/Users/ryznerf/Documents/0_MIT/Spring_2022/0_Projects/3_Networks_project/community-detetction-deep-learning/Data/'
files = ['toy_dataset.pkl', 'complex_1.pkl', 'complex_2.pkl']

# %%
# CASE 1
g = Utils.unpickle_object(data_folder + files[0])
true, pred = Non_DL_Methods.Louvain_algorithm(g)
NMI = normalized_mutual_info_score(np.array(list(true.values())), np.array(list(pred.values())))
Plotting.graph_cluster_plot(g=g, partition=pred, title='Predicted - Louvain case 1 - NMI: ' + str(np.round(NMI, 3)))

# %%
# CASE 2
g = Utils.unpickle_object(data_folder + files[1])
true, pred = Non_DL_Methods.Louvain_algorithm(g)
NMI = normalized_mutual_info_score(np.array(list(true.values())), np.array(list(pred.values())))
Plotting.graph_cluster_plot(g=g, partition=pred, title='Predicted - Louvain case 2 - NMI: ' + str(np.round(NMI, 3)))

# %%
# CASE 3
g = Utils.unpickle_object(data_folder + files[2])
true, pred = Non_DL_Methods.Louvain_algorithm(g)
NMI = normalized_mutual_info_score(np.array(list(true.values())), np.array(list(pred.values())))
print(NMI)
Plotting.graph_cluster_plot(g=g, partition=pred, title='Predicted - Louvain case 3 - NMI: ' + str(np.round(NMI, 3)))
# Out:
# 0.2859268799402471

# %% [markdown]
# Spectral clustering

# %%
# CASE 1
g = Utils.unpickle_object(data_folder + files[0])
true, pred = Non_DL_Methods.Spectral_Clustering(g)
NMI = normalized_mutual_info_score(np.array(list(true.values())), np.array(list(pred.values())))
Plotting.graph_cluster_plot(g=g, partition=pred, title='Predicted - Spectral Clustering case 1 - NMI: ' + str(np.round(NMI, 3)))

# %%
# CASE 2
g = Utils.unpickle_object(data_folder + files[1])
true, pred = Non_DL_Methods.Spectral_Clustering(g)
NMI = normalized_mutual_info_score(np.array(list(true.values())), np.array(list(pred.values())))
Plotting.graph_cluster_plot(g=g, partition=pred, title='Predicted - Spectral Clustering case 2 - NMI: ' + str(np.round(NMI, 3)))

# %%
# CASE 3
g = Utils.unpickle_object(data_folder + files[2])
true, pred = Non_DL_Methods.Spectral_Clustering(g)
NMI = normalized_mutual_info_score(np.array(list(true.values())), np.array(list(pred.values())))
Plotting.graph_cluster_plot(g=g, partition=pred, title='Predicted - Spectral Clustering case 3 - NMI: ' + str(np.round(NMI, 3)))

# %%
import networkx
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap

name = "Accent_r"

cmap = get_cmap(name, lut = 100)
colors = cmap.colors

# %%
len(colors)
# Out:
# 100

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('viridis', 100)

# %%
len(np.unique(list(pred.values())))
# Out:
# 10

# %%
g = Utils.unpickle_object(data_folder + files[0])
x = Utils.unpickle_object('/Users/ryznerf/Documents/0_MIT/Spring_2022/0_Projects/3_Networks_project/community-detetction-deep-learning/test1.pkl')
pred = {}
for i in range(len(x)):
    pred[i] = x[i]

# %%
Plotting.graph_cluster_plot(g=g, partition=pred, title='Predicted - Min-Cut 1 - NMI: 0.41')

# %%
g = Utils.unpickle_object(data_folder + files[1])
x = Utils.unpickle_object('/Users/ryznerf/Documents/0_MIT/Spring_2022/0_Projects/3_Networks_project/community-detetction-deep-learning/test2.pkl')
pred = {}
for i in range(len(x)):
    pred[i] = x[i]
Plotting.graph_cluster_plot(g=g, partition=pred, title='Predicted - Min-Cut 2 - NMI: 0.018')

# %%
g = Utils.unpickle_object(data_folder + files[2])
x = Utils.unpickle_object('/Users/ryznerf/Documents/0_MIT/Spring_2022/0_Projects/3_Networks_project/community-detetction-deep-learning/test3.pkl')
pred = {}
for i in range(len(x)):
    pred[i] = x[i]
Plotting.graph_cluster_plot(g=g, partition=pred, title='Predicted - Min-Cut 3 - NMI: 0.111')
