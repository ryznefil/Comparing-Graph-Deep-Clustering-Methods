# %%
# !git clone https://github.com/FilippoMB/Spectral-Clustering-with-Graph-Neural-Networks-for-Graph-Pooling.git
# Out:
# Cloning into 'Spectral-Clustering-with-Graph-Neural-Networks-for-Graph-Pooling'...
# remote: Enumerating objects: 116, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 116 (delta 15), reused 5 (delta 5), pack-reused 98
# Receiving objects: 100% (116/116), 2.99 MiB | 9.24 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
import os
os.chdir(os.path.join(os.getcwd(), 'Spectral-Clustering-with-Graph-Neural-Networks-for-Graph-Pooling'))

# %%
# !sudo apt-get install python3-dev graphviz libgraphviz-dev pkg-config
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# graphviz is already the newest version (2.40.1-2).
# python3-dev is already the newest version (3.6.7-1~18.04).
# python3-dev set to manually installed.
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'sudo apt autoremove' to remove them.
# The following additional packages will be installed:
#   libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin libgtk2.0-common
#   libgvc6-plugins-gtk libxdot4
# Suggested packages:
#   gvfs
# The following NEW packages will be installed:
#   libgail-common libgail18 libgraphviz-dev libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libgvc6-plugins-gtk libxdot4
# 0 upgraded, 8 newly installed, 0 to remove and 42 not upgraded.
# Need to get 2,120 kB of archives.
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 104 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 157 kB 36.9 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 54.6 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 30.9 MB/s
# ...
#      |████████████████████████████████| 58 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 52.1 MB/s
# ...
#      |████████████████████████████████| 294 kB 41.2 MB/s
# ...
#      |████████████████████████████████| 312 kB 60.1 MB/s
# ...
#      |████████████████████████████████| 50 kB 5.8 MB/s
# ...
#      |████████████████████████████████| 90 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 5.5 MB 18.3 MB/s
# ...
#      |████████████████████████████████| 88 kB 4.1 MB/s
# ...
#      |████████████████████████████████| 13.0 MB 43.4 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 43.0 MB/s
# ...
#      |████████████████████████████████| 20.2 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 10.1 MB 33.5 MB/s
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !rm -r logs
# !python Spectral-Clustering-with-Graph-Neural-Networks-for-Graph-Pooling/Clustering.py
# Out:
# Using TensorFlow backend.
# OrderedDict([('dataset', 'custom_mustafa'), ('method', 'mincut_pool'), ('H_', None), ('n_channels', 32), ('learning_rate', 0.0005)])
# CUSTOM DATASET
# 2022-05-01 03:45:21.368171: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-05-01 03:45:21.374815: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# 2022-05-01 03:45:21.375119: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x20e0a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-05-01 03:45:21.375160: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 100% 20000/20000 [01:23<00:00, 238.52it/s]
# MinCutPool - HOMO: 0.43271508942404346, CS: 0.3919155078420402, NMI: 0.41130599467149515
# <Figure size 640x480 with 0 Axes>
# ...

# %%
# !zip -r /content/file.zip /content/Spectral-Clustering-with-Graph-Neural-Networks-for-Graph-Pooling
# Out:
#   adding: content/Spectral-Clustering-with-Graph-Neural-Networks-for-Graph-Pooling/ (stored 0%)
#   adding: content/Spectral-Clustering-with-Graph-Neural-Networks-for-Graph-Pooling/Autoencoder.py (deflated 64%)
#   adding: content/Spectral-Clustering-with-Graph-Neural-Networks-for-Graph-Pooling/utils/ (stored 0%)
#   adding: content/Spectral-Clustering-with-Graph-Neural-Networks-for-Graph-Pooling/utils/citation.py (deflated 59%)
#   adding: content/Spectral-Clustering-with-Graph-Neural-Networks-for-Graph-Pooling/utils/misc.py (deflated 64%)
#   adding: content/Spectral-Clustering-with-Graph-Neural-Networks-for-Graph-Pooling/utils/dataset_loader.py (deflated 70%)
#   adding: content/Spectral-Clustering-with-Graph-Neural-Networks-for-Graph-Pooling/utils/__pycache__/ (stored 0%)
#   adding: content/Spectral-Clustering-with-Graph-Neural-Networks-for-Graph-Pooling/utils/__pycache__/citation.cpython-37.pyc (deflated 40%)
# ...
